# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.simplefilter('ignore')

# %%
df_train=pd.read_csv('movies_train.csv', index_col='title')
df_test=pd.read_csv('movies_test.csv', index_col='title')
submission=pd.read_csv('movies_submission.csv', index_col='title')
data=df_train

df_train_len = len(df_train)
df_test_len = len(df_test)

# %%
df_train.head()
# Out:
#             distributor genre release_time  time screening_rat director  \
# title
# 개들의 전쟁         롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 내부자들             (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 나는 공무원이다         (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 불량남녀       쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#            dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# title
# 개들의 전쟁                NaN             0         91          2        23398
# 내부자들           1161602.50             2        387          3      7072501
# 은밀하게 위대하게       220775.25             4        343          4      6959083
# 나는 공무원이다         23894.00             2         20          6       217866
# 불량남녀                 1.00             1        251          2       483387

# %%
# corr()함수를 통해 dataframe내의 모든 변수간의 상관관계가 0.1이상인 변수만 heatmap 출력

corrmat = df_train.corr()
top_corr_features = corrmat.index
top_corr_features
# Out:
# Index(['time', 'dir_prev_bfnum', 'dir_prev_num', 'num_staff', 'num_actor',
#        'box_off_num'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
g = sns.heatmap(df_train[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
# title : 영화의 제목
# distributor : 배급사
# genre : 장르
# release_time : 개봉일
# time : 상영시간(분)
# screening_rat : 상영등급
# director : 감독이름
# dir_prev_bfnum : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수(단 관객수가 알려지지 않은 영화 제외)
# dir_prev_num : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화의 개수(단 관객수가 알려지지 않은 영화 제외)
# num_staff : 스텝수
# num_actor : 주연배우수
# box_off_num : 관객수

# %%
y_train = df_train['box_off_num']

# %%
# df_train = df_train[list(df_test)]
# print(list(df_train))
# print(list(df_test))

# %%
# all_data = pd.concat((df_train, df_test), axis=0)
# print('Length of alldata : ', len(all_data))
# print(all_data.shape)
# all_data.head()
# Out:
# Length of alldata :  843
# (843, 11)
#             distributor genre release_time  time screening_rat director  \
# title
# 개들의 전쟁         롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 내부자들             (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 나는 공무원이다         (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 불량남녀       쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#            dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# title
# 개들의 전쟁                NaN             0         91          2      23398.0
# 내부자들           1161602.50             2        387          3    7072501.0
# 은밀하게 위대하게       220775.25             4        343          4    6959083.0
# 나는 공무원이다         23894.00             2         20          6     217866.0
# 불량남녀                 1.00             1        251          2     483387.0

# %%
sns.regplot(df_train['num_staff'], df_train['box_off_num']) # num_staff
# Out:
# <AxesSubplot:xlabel='num_staff', ylabel='box_off_num'>

# %%
df_train = df_train.drop(df_train[(df_train['num_staff']>800)].index)

# %%
sns.regplot(df_train['time'], df_train['box_off_num']) # time
# Out:
# <AxesSubplot:xlabel='time', ylabel='box_off_num'>

# %%
df_train = df_train.drop(df_train[(df_train['num_staff']>170)].index)

# %%
sns.regplot(df_train['time'], df_train['box_off_num']) # time
# Out:
# <AxesSubplot:xlabel='time', ylabel='box_off_num'>

# %%
# title : 영화의 제목
# distributor : 배급사
# genre : 장르
# release_time : 개봉일
# time : 상영시간(분)
# screening_rat : 상영등급
# director : 감독이름
# dir_prev_bfnum : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수(단 관객수가 알려지지 않은 영화 제외)
# dir_prev_num : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화의 개수(단 관객수가 알려지지 않은 영화 제외)
# num_staff : 스텝수
# num_actor : 주연배우수
# box_off_num : 관객수

# %%
y_train = df_train['box_off_num']
df_train = df_train[list(df_test)]

# %%
all_data = pd.concat((df_train, df_test), axis=0)
print(all_data.shape)
# Out:
# (635, 10)

# %%
# 이 영화를 만들기 전 영화 관련

figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
figure.set_size_inches(12,6)
sns.regplot(data['dir_prev_bfnum'], data['box_off_num'], ax=ax1)
sns.regplot(data['dir_prev_num'], data['box_off_num'], ax=ax2)
sns.regplot((data['dir_prev_bfnum']+data['dir_prev_num']) / 2, data['box_off_num'], ax=ax3) #'/2' for graph scaling

all_data['total_dir_prev'] = (all_data['dir_prev_bfnum']+all_data['dir_prev_num'])  / 2

# %%
all_data_obj = all_data.select_dtypes(include='object') # 카테고리형
all_data_num = all_data.select_dtypes(exclude='object') # 수치형

print('Object type columns:\n', all_data_obj.columns)
print('-----------------------------------------------------------------------')
print('Numeric type columns:\n', all_data_num.columns)
# Out:
# Object type columns:
#  Index(['distributor', 'genre', 'release_time', 'screening_rat', 'director'], dtype='object')
# -----------------------------------------------------------------------
# Numeric type columns:
#  Index(['time', 'dir_prev_bfnum', 'dir_prev_num', 'num_staff', 'num_actor',
#        'total_dir_prev'],
#       dtype='object')

# %%
all_data_num = all_data_num.fillna(all_data_num.mean())
# 결측 값을 각열의 평균값으로 대체
all_data_num
# Out:
#                  time  dir_prev_bfnum  dir_prev_num  num_staff  num_actor  \
# title
# 개들의 전쟁             96   723615.033697             0         91          2
# 나는 공무원이다          101    23894.000000             2         20          6
# 길위에서              104   723615.033697             0         32          5
# 1789, 바스티유의 연인들   129   723615.033697             0          3          5
# 청춘그루브              94   723615.033697             0        138          3
# ...               ...             ...           ...        ...        ...
# 해에게서 소년에게          78     2590.000000             1          4          4
# 울보 권투부             86   723615.033697             0         18          2
# 어떤살인              107   723615.033697             0        224          4
# 말하지 못한 비밀         102    50699.000000             1         68          7
# 조선안방 스캔들-칠거지악 2    76   723615.033697             0         10          4
#
#                  total_dir_prev
# title
# 개들의 전쟁            361808.409862
# 나는 공무원이다           11948.000000
# 길위에서              361808.409862
# 1789, 바스티유의 연인들   361808.409862
# 청춘그루브             361808.409862
# ...                         ...
# 해에게서 소년에게           1295.500000
# 울보 권투부            361808.409862
# 어떤살인              361808.409862
# 말하지 못한 비밀          25350.000000
# 조선안방 스캔들-칠거지악 2   361808.409862
#
# [635 rows x 6 columns]

# %%
# Chanhe object type to dummy variables
'''
위에서 분리한 카테고리형 데이터에 one-hot encoding 적용(get_dummies())
'''
all_data_dummy = pd.get_dummies(all_data_obj, drop_first=True)
all_data_dummy
# Out:
#                  distributor_(주) 브릿지웍스  distributor_(주) 액티버스엔터테인먼트  \
# title
# 개들의 전쟁                               0                           0
# 나는 공무원이다                             0                           0
# 길위에서                                 0                           0
# 1789, 바스티유의 연인들                      0                           0
# 청춘그루브                                0                           0
# ...                                ...                         ...
# 해에게서 소년에게                            0                           0
# 울보 권투부                               0                           0
# 어떤살인                                 0                           0
# 말하지 못한 비밀                            0                           0
# 조선안방 스캔들-칠거지악 2                      0                           0
#
#                  distributor_(주) 영화사조제  distributor_(주) 영화제작전원사  \
# title
# 개들의 전쟁                               0                        0
# 나는 공무원이다                             0                        0
# 길위에서                                 0                        0
# 1789, 바스티유의 연인들                      0                        0
# 청춘그루브                                0                        0
# ...                                ...                      ...
# 해에게서 소년에게                            0                        0
# 울보 권투부                               0                        0
# 어떤살인                                 0                        0
# 말하지 못한 비밀                            0                        0
# 조선안방 스캔들-칠거지악 2                      0                        0
#
#                  distributor_(주) 케이알씨지  distributor_(주)NEW  \
# title
# 개들의 전쟁                               0                   0
# 나는 공무원이다                             0                   1
# 길위에서                                 0                   0
# 1789, 바스티유의 연인들                      0                   0
# 청춘그루브                                0                   0
# ...                                ...                 ...
# 해에게서 소년에게                            0                   0
# 울보 권투부                               0                   0
# 어떤살인                                 0                   0
# 말하지 못한 비밀                            0                   0
# 조선안방 스캔들-칠거지악 2                      1                   0
#
#                  distributor_(주)고앤고 필름  distributor_(주)노버스엔터테인먼트  \
# title
# 개들의 전쟁                               0                         0
# 나는 공무원이다                             0                         0
# 길위에서                                 0                         0
# 1789, 바스티유의 연인들                      0                         0
# 청춘그루브                                0                         0
# ...                                ...                       ...
# 해에게서 소년에게                            0                         0
# 울보 권투부                               0                         0
# 어떤살인                                 0                         0
# 말하지 못한 비밀                            0                         0
# 조선안방 스캔들-칠거지악 2                      0                         0
#
#                  distributor_(주)다세포클럽  distributor_(주)대명문화공장  ...  \
# title                                                         ...
# 개들의 전쟁                              0                      0  ...
# 나는 공무원이다                            0                      0  ...
# 길위에서                                0                      0  ...
# 1789, 바스티유의 연인들                     0                      0  ...
# 청춘그루브                               0                      0  ...
# ...                               ...                    ...  ...
# 해에게서 소년에게                           0                      0  ...
# 울보 권투부                              0                      0  ...
# 어떤살인                                0                      0  ...
# 말하지 못한 비밀                           0                      0  ...
# 조선안방 스캔들-칠거지악 2                     0                      0  ...
#
#                  director_홍리경  director_홍상수  director_홍재희  director_홍형숙  \
# title
# 개들의 전쟁                      0             0             0             0
# 나는 공무원이다                    0             0             0             0
# 길위에서                        0             0             0             0
# 1789, 바스티유의 연인들             0             0             0             0
# 청춘그루브                       0             0             0             0
# ...                       ...           ...           ...           ...
# 해에게서 소년에게                   0             0             0             0
# 울보 권투부                      0             0             0             0
# 어떤살인                        0             0             0             0
# 말하지 못한 비밀                   0             0             0             0
# 조선안방 스캔들-칠거지악 2             0             0             0             0
#
#                  director_황동혁  director_황석호  director_황욱  director_황유식  \
# title
# 개들의 전쟁                      0             0            0             0
# 나는 공무원이다                    0             0            0             0
# 길위에서                        0             0            0             0
# 1789, 바스티유의 연인들             0             0            0             0
# 청춘그루브                       0             0            0             0
# ...                       ...           ...          ...           ...
# 해에게서 소년에게                   0             0            0             0
# 울보 권투부                      0             0            0             0
# 어떤살인                        0             0            0             0
# 말하지 못한 비밀                   0             0            0             0
# 조선안방 스캔들-칠거지악 2             0             0            0             0
#
#                  director_황윤  director_황철민
# title
# 개들의 전쟁                     0             0
# 나는 공무원이다                   0             0
# 길위에서                       0             0
# 1789, 바스티유의 연인들            0             0
# 청춘그루브                      0             0
# ...                      ...           ...
# 해에게서 소년에게                  0             0
# 울보 권투부                     0             0
# 어떤살인                       0             0
# 말하지 못한 비밀                  0             0
# 조선안방 스캔들-칠거지악 2            0             0
#
# [635 rows x 1006 columns]

# %%
# Merge numeric_df & dummies_df
'''
# 위에서 각각 처리한 카테고리형 데이터와 수치형 데이터를 최종적으로 다시 하나로 merge해준다
# merge시 index 순서가 꼬이지 않게 left_index=True, right_index=True를 지정하여 merge 수행
'''

all_data = pd.merge(all_data_dummy, all_data_num, left_index=True, right_index=True)
all_data.shape
# Out:
# (635, 1012)

# %%
X_train = all_data[:len(df_train)]
X_test = all_data[len(df_train):]

X_train['box_off_num'] = y_train

print(X_train.shape)
print(X_test.shape)
# Out:
# (392, 1013)
# (243, 1012)

# %%
from pycaret.regression import *

# %%
reg = setup(X_train, target='box_off_num', train_size=0.8)
# Out:
# <style type="text/css">
# #T_379b6_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_379b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_379b6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_379b6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_379b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_379b6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_379b6_row0_col1" class="data row0 col1" >4452</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_379b6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_379b6_row1_col1" class="data row1 col1" >box_off_num</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_379b6_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_379b6_row2_col1" class="data row2 col1" >(392, 1013)</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_379b6_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_379b6_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_379b6_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_379b6_row4_col1" class="data row4 col1" >1010</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_379b6_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_379b6_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_379b6_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_379b6_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_379b6_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_379b6_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_379b6_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_379b6_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_379b6_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_379b6_row9_col1" class="data row9 col1" >(313, 842)</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_379b6_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_379b6_row10_col1" class="data row10 col1" >(79, 842)</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_379b6_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_379b6_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_379b6_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_379b6_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_379b6_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_379b6_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_379b6_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_379b6_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_379b6_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_379b6_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_379b6_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_379b6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_379b6_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_379b6_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_379b6_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_379b6_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_379b6_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_379b6_row19_col1" class="data row19 col1" >aa9e</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_379b6_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_379b6_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_379b6_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_379b6_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_379b6_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_379b6_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_379b6_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_379b6_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_379b6_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_379b6_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_379b6_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_379b6_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_379b6_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_379b6_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_379b6_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_379b6_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_379b6_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_379b6_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_379b6_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_379b6_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_379b6_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_379b6_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_379b6_row30_col1

# %%
best_model = compare_models(sort = 'RMSE')
# Out:
# <style type="text/css">
# #T_dd0f4 th {
#   text-align: left;
# }
# #T_dd0f4_row0_col0, #T_dd0f4_row0_col2, #T_dd0f4_row0_col5, #T_dd0f4_row1_col0, #T_dd0f4_row1_col1, #T_dd0f4_row1_col3, #T_dd0f4_row1_col4, #T_dd0f4_row1_col6, #T_dd0f4_row2_col0, #T_dd0f4_row2_col1, #T_dd0f4_row2_col2, #T_dd0f4_row2_col3, #T_dd0f4_row2_col4, #T_dd0f4_row2_col5, #T_dd0f4_row2_col6, #T_dd0f4_row3_col0, #T_dd0f4_row3_col1, #T_dd0f4_row3_col2, #T_dd0f4_row3_col3, #T_dd0f4_row3_col4, #T_dd0f4_row3_col5, #T_dd0f4_row3_col6, #T_dd0f4_row4_col0, #T_dd0f4_row4_col1, #T_dd0f4_row4_col2, #T_dd0f4_row4_col3, #T_dd0f4_row4_col4, #T_dd0f4_row4_col5, #T_dd0f4_row4_col6, #T_dd0f4_row5_col0, #T_dd0f4_row5_col1, #T_dd0f4_row5_col2, #T_dd0f4_row5_col3, #T_dd0f4_row5_col4, #T_dd0f4_row5_col5, #T_dd0f4_row5_col6, #T_dd0f4_row6_col0, #T_dd0f4_row6_col1, #T_dd0f4_row6_col2, #T_dd0f4_row6_col3, #T_dd0f4_row6_col4, #T_dd0f4_row6_col5, #T_dd0f4_row6_col6, #T_dd0f4_row7_col0, #T_dd0f4_row7_col1, #T_dd0f4_row7_col2, #T_dd0f4_row7_col3, #T_dd0f4_row7_col4, #T_dd0f4_row7_col5, #T_dd0f4_row7_col6, #T_dd0f4_row8_col0, #T_dd0f4_row8_col1, #T_dd0f4_row8_col2, #T_dd0f4_row8_col3, #T_dd0f4_row8_col4, #T_dd0f4_row8_col5, #T_dd0f4_row8_col6, #T_dd0f4_row9_col0, #T_dd0f4_row9_col1, #T_dd0f4_row9_col2, #T_dd0f4_row9_col3, #T_dd0f4_row9_col4, #T_dd0f4_row9_col5, #T_dd0f4_row9_col6, #T_dd0f4_row10_col0, #T_dd0f4_row10_col1, #T_dd0f4_row10_col2, #T_dd0f4_row10_col3, #T_dd0f4_row10_col4, #T_dd0f4_row10_col5, #T_dd0f4_row10_col6, #T_dd0f4_row11_col0, #T_dd0f4_row11_col1, #T_dd0f4_row11_col2, #T_dd0f4_row11_col3, #T_dd0f4_row11_col4, #T_dd0f4_row11_col5, #T_dd0f4_row11_col6, #T_dd0f4_row12_col0, #T_dd0f4_row12_col1, #T_dd0f4_row12_col2, #T_dd0f4_row12_col3, #T_dd0f4_row12_col4, #T_dd0f4_row12_col5, #T_dd0f4_row12_col6, #T_dd0f4_row13_col0, #T_dd0f4_row13_col1, #T_dd0f4_row13_col2, #T_dd0f4_row13_col3, #T_dd0f4_row13_col4, #T_dd0f4_row13_col5, #T_dd0f4_row13_col6, #T_dd0f4_row14_col0, #T_dd0f4_row14_col1, #T_dd0f4_row14_col2, #T_dd0f4_row14_col3, #T_dd0f4_row14_col4, #T_dd0f4_row14_col5, #T_dd0f4_row14_col6, #T_dd0f4_row15_col0, #T_dd0f4_row15_col1, #T_dd0f4_row15_col2, #T_dd0f4_row15_col3, #T_dd0f4_row15_col4, #T_dd0f4_row15_col5, #T_dd0f4_row15_col6, #T_dd0f4_row16_col0, #T_dd0f4_row16_col1, #T_dd0f4_row16_col2, #T_dd0f4_row16_col3, #T_dd0f4_row16_col4, #T_dd0f4_row16_col5, #T_dd0f4_row16_col6 {
#   text-align: left;
# }
# #T_dd0f4_row0_col1, #T_dd0f4_row0_col3, #T_dd0f4_row0_col4, #T_dd0f4_row0_col6, #T_dd0f4_row1_col2, #T_dd0f4_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dd0f4_row0_col7, #T_dd0f4_row1_col7, #T_dd0f4_row3_col7, #T_dd0f4_row4_col7, #T_dd0f4_row5_col7, #T_dd0f4_row6_col7, #T_dd0f4_row7_col7, #T_dd0f4_row8_col7, #T_dd0f4_row9_col7, #T_dd0f4_row10_col7, #T_dd0f4_row11_col7, #T_dd0f4_row12_col7, #T_dd0f4_row13_col7, #T_dd0f4_row14_col7, #T_dd0f4_row15_col7, #T_dd0f4_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_dd0f4_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dd0f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd0f4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dd0f4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_dd0f4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dd0f4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_dd0f4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_dd0f4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_dd0f4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_dd0f4_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd0f4_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_dd0f4_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_dd0f4_row0_col1" class="data row0 col1" >160113.0695</td>
#       <td id="T_dd0f4_row0_col2" class="data row0 col2" >623209306959.0079</td>
#       <td id="T_dd0f4_row0_col3" class="data row0 col3" >595287.0443</td>
#       <td id="T_dd0f4_row0_col4" class="data row0 col4" >-0.0925</td>
#       <td id="T_dd0f4_row0_col5" class="data row0 col5" >3.2999</td>
#       <td id="T_dd0f4_row0_col6" class="data row0 col6" >36.6713</td>
#       <td id="T_dd0f4_row0_col7" class="data row0 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f4_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_dd0f4_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_dd0f4_row1_col1" class="data row1 col1" >181918.5463</td>
#       <td id="T_dd0f4_row1_col2" class="data row1 col2" >576291757816.1420</td>
#       <td id="T_dd0f4_row1_col3" class="data row1 col3" >597318.2786</td>
#       <td id="T_dd0f4_row1_col4" class="data row1 col4" >-6.5146</td>
#       <td id="T_dd0f4_row1_col5" class="data row1 col5" >2.5367</td>
#       <td id="T_dd0f4_row1_col6" class="data row1 col6" >614.0000</td>
#       <td id="T_dd0f4_row1_col7" class="data row1 col7" >0.1670</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f4_level0_row2" class="row_heading level0 row2" >dummy</th>
#       <td id="T_dd0f4_row2_col0" class="data row2 col0" >Dummy Regressor</td>
#       <td id="T_dd0f4_row2_col1" class="data row2 col1" >274722.7117</td>
#       <td id="T_dd0f4_row2_col2" class="data row2 col2" >603133842144.8167</td>
#       <td id="T_dd0f4_row2_col3" class="data row2 col3" >607367.1570</td>
#       <td id="T_dd0f4_row2_col4" class="data row2 col4" >-6.4112</td>
#       <td id="T_dd0f4_row2_col5" class="data row2 col5" >4.4710</td>
#       <td id="T_dd0f4_row2_col6" class="data row2 col6" >865.5723</td>
#       <td id="T_dd0f4_row2_col7" class="data row2 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f4_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_dd0f4_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_dd0f4_row3_col1" class="data row3 col1" >191877.6157</td>
#       <td id="T_dd0f4_row3_col2" class="data row3 col2" >628013527278.3936</td>
#       <td id="T_dd0f4_row3_col3" class="data row3 col3" >640828.7278</td>
#       <td id="T_dd0f4_row3_col4" class="data row3 col4" >-3.0403</td>
#       <td id="T_dd0f4_row3_col5" class="data row3 col5" >2.6334</td>
#       <td id="T_dd0f4_row3_col6" class="data row3 col6" >357.3323</td>
#       <td id="T_dd0f4_row3_col7" class="data row3 col7" >0.2350</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f4_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_dd0f4_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_dd0f4_row4_col1" class="data row4 col1" >207352.9753</td>
#       <td id="T_dd0f4_row4_col2" class="data row4 col2" >627397224552.4430</td>
#       <td id="T_dd0f4_row4_col3" class="data row4 col3" >644648.6200</td>
#       <td id="T_dd0f4_row4_col4" class="data row4 col4" >-2.9781</td>
#       <td id="T_dd0f4_row4_col5" class="data row4 col5" >2.9881</td>
#       <td id="T_dd0f4_row4_col6" class="data row4 col6" >679.3136</td>
#       <td id="T_dd0f4_row4_col7" class="data row4 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f4_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_dd0f4_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_dd0f4_row5_col1" class="data row5 col1" >291939.7462</td>
#       <td id="T_dd0f4_row5_col2" class="data row5 col2" >595203976837.5178</td>
#       <td id="T_dd0f4_row5_col3" class="data row5 col3" >655532.1733</td>
#       <td id="T_dd0f4_row5_col4" class="data row5 col4" >-14.9255</td>
#       <td id="T_dd0f4_row5_col5" class="data row5 col5" >4.0333</td>
#       <td id="T_dd0f4_row5_col6" class="data row5 col6" >390.2357</td>
#       <td id="T_dd0f4_row5_col7" class="data row5 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f4_level0_row6" class="row_heading level0

# %%
huber = create_model('huber', cross_validation=False)
# Out:
#           MAE           MSE        RMSE      R2   RMSLE     MAPE
# 0  27534.2327  9.854489e+09  99269.7771 -0.0735  3.1952  17.6969

# %%
tuned_huber = tune_model(huber, optimize='RMSE', n_iter=10)
final_model = finalize_model(tuned_huber)
prediction_huber = predict_model(final_model, data=X_test)
# Out:
# <style type="text/css">
# #T_f511b_row10_col0, #T_f511b_row10_col1, #T_f511b_row10_col2, #T_f511b_row10_col3, #T_f511b_row10_col4, #T_f511b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f511b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f511b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f511b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f511b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f511b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f511b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f511b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f511b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f511b_row0_col0" class="data row0 col0" >50839.4082</td>
#       <td id="T_f511b_row0_col1" class="data row0 col1" >15406343500.1393</td>
#       <td id="T_f511b_row0_col2" class="data row0 col2" >124122.2925</td>
#       <td id="T_f511b_row0_col3" class="data row0 col3" >-0.1846</td>
#       <td id="T_f511b_row0_col4" class="data row0 col4" >3.6469</td>
#       <td id="T_f511b_row0_col5" class="data row0 col5" >268.4915</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f511b_row1_col0" class="data row1 col0" >8803.7945</td>
#       <td id="T_f511b_row1_col1" class="data row1 col1" >524614130.3662</td>
#       <td id="T_f511b_row1_col2" class="data row1 col2" >22904.4566</td>
#       <td id="T_f511b_row1_col3" class="data row1 col3" >-0.1470</td>
#       <td id="T_f511b_row1_col4" class="data row1 col4" >2.8036</td>
#       <td id="T_f511b_row1_col5" class="data row1 col5" >3.4518</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f511b_row2_col0" class="data row2 col0" >210978.5662</td>
#       <td id="T_f511b_row2_col1" class="data row2 col1" >709179898391.3241</td>
#       <td id="T_f511b_row2_col2" class="data row2 col2" >842128.1959</td>
#       <td id="T_f511b_row2_col3" class="data row2 col3" >-0.0565</td>
#       <td id="T_f511b_row2_col4" class="data row2 col4" >2.4116</td>
#       <td id="T_f511b_row2_col5" class="data row2 col5" >7.3433</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f511b_row3_col0" class="data row3 col0" >30238.6229</td>
#       <td id="T_f511b_row3_col1" class="data row3 col1" >16678221130.6917</td>
#       <td id="T_f511b_row3_col2" class="data row3 col2" >129144.1874</td>
#       <td id="T_f511b_row3_col3" class="data row3 col3" >-0.0585</td>
#       <td id="T_f511b_row3_col4" class="data row3 col4" >2.1786</td>
#       <td id="T_f511b_row3_col5" class="data row3 col5" >1.8775</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f511b_row4_col0" class="data row4 col0" >383392.1423</td>
#       <td id="T_f511b_row4_col1" class="data row4 col1" >2870101929305.4150</td>
#       <td id="T_f511b_row4_col2" class="data row4 col2" >1694137.5178</td>
#       <td id="T_f511b_row4_col3" class="data row4 col3" >-0.0532</td>
#       <td id="T_f511b_row4_col4" class="data row4 col4" >2.8116</td>
#       <td id="T_f511b_row4_col5" class="data row4 col5" >2.8458</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f511b_row5_col0" class="data row5 col0" >429252.7920</td>
#       <td id="T_f511b_row5_col1" class="data row5 col1" >1801352017896.3101</td>
#       <td id="T_f511b_row5_col2" class="data row5 col2" >1342144.5592</td>
#       <td id="T_f511b_row5_col3" class="data row5 col3" >-0.1119</td>
#       <td id="T_f511b_row5_col4" class="data row5 col4" >3.9896</td>
#       <td id="T_f511b_row5_col5" class="data row5 col5" >2.9380</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f511b_row6_col0" class="data row6 col0" >193649.7225</td>
#       <td id="T_f511b_row6_col1" class="data row6 col1" >252491477863.3150</td>
#       <td id="T_f511b_row6_col2" class="data row6 col2" >502485.3011</td>
#       <td id="T_f511b_row6_col3" class="data row6 col3" >-0.1682</td>
#       <td id="T_f511b_row6_col4" class="data row6 col4" >2.8604</td>
#       <td id="T_f511b_row6_col5" class="data row6 col5" >3.5997</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f511b_row7_col0" class="data row7 col0" >82965.7632</td>
#       <td id="T_f511b_row7_col1" class="data row7 col1" >161127966111.8934</td>
#       <td id="T_f511b_row7_col2" class="data row7 col2" >401407.4814</td>
#       <td id="T_f511b_row7_col3" class="data row7 col3" >-0.0346</td>
#       <td id="T_f511b_row7_col4" class="data row7 col4" >3.0130</td>
#       <td id="T_f511b_row7_col5" class="data row7 col5" >1.3207</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f511b_row8_col0" class="data row8 col0" >124840.0572</td>
#       <td id="T_f511b_row8_col1" class="data row8 col1" >224363291647.1806</td>
#       <td id="T_f511b_row8_col2" class="data row8 col2" >473670.0240</td>
#       <td id="T_f511b_row8_col3" class="data row8 col3" >-0.0560</td>
#       <td id="T_f511b_row8_col4" class="data row8 col4" >3.1908</td>
#       <td id="T_f511b_row8_col5" class="data row8 col5" >79.9896</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f511b_row9_col0" class="data row9 col0" >87087.7678</td>
#       <td id="T_f511b_row9_col1" class="data row9 col1" >173731574837.0705</td>
#       <td id="T_f511b_row9_col2" class="data row9 col2" >416811.1981</td>
#       <td id="T_f511b_row9_col3" class="data row9 col3" >-0.0444</td>
#       <td id="T_f511b_row9_col4" class="data row9 col4" >3.0575</td>
#       <td id="T_f511b_row9_col5" class="data row9 col5" >1.3218</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f511b_row10_col0" class="data row10 col0" >160204.8637</td>
#       <td id="T_f511b_row10_col1" class="data row10 col1" >622495733481.3705</td>
#       <td id="T_f511b_row10_col2" class="data row10 col2" >594895.5214</td>
#       <td id="T_f511b_row10_col3" class="data row10 col3" >-0.0915</td>
#       <td id="T_f511b_row10_col4" class="data row10 col4" >2.9964</td>
#       <td id="T_f511b_row10_col5" class="data row10 col5" >37.3180</td>
#     </tr>
#     <tr>
#       <th id="T_f511b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f511b_row11_col0" class="data row11 col0" >137924.9233</td>
#       <td id="T_f511b_row11_col1" class="data row11 col1" >910001781950.4644</td>
#       <td id="T_f511b_row11_col2" class="data row11 col2" >518261.5673</td>
#       <td id="T_f511b_row11_col3" class="data row11 col3" >0.0534</td>
#       <td id="T_f511b_row11_col4" class="data row11 col4" >0.5052</td>
#       <td id="T_f511b_row11_col5" class="data row11 col5" >80.4128</td>
#     </tr>
#   </tbody>
# </table>

# %%
prediction_huber.head()
# Out:
#              distributor_(주) 브릿지웍스  distributor_(주) 액티버스엔터테인먼트  \
# title
# 용서는 없다                           0                           0
# 아빠가 여자를 좋아해                      0                           0
# 하모니                              0                           0
# 의형제                              0                           0
# 평행 이론                            0                           0
#
#              distributor_(주) 영화사조제  distributor_(주) 영화제작전원사  \
# title
# 용서는 없다                           0                        0
# 아빠가 여자를 좋아해                      0                        0
# 하모니                              0                        0
# 의형제                              0                        0
# 평행 이론                            0                        0
#
#              distributor_(주) 케이알씨지  distributor_(주)NEW  distributor_(주)고앤고 필름  \
# title
# 용서는 없다                           0                   0                      0
# 아빠가 여자를 좋아해                      0                   0                      0
# 하모니                              0                   0                      0
# 의형제                              0                   0                      0
# 평행 이론                            0                   0                      0
#
#              distributor_(주)노버스엔터테인먼트  distributor_(주)다세포클럽  \
# title
# 용서는 없다                              0                     0
# 아빠가 여자를 좋아해                         0                     0
# 하모니                                 0                     0
# 의형제                                 0                     0
# 평행 이론                               0                     0
#
#              distributor_(주)대명문화공장  ...  director_황유식  director_황윤  \
# title                               ...
# 용서는 없다                           0  ...             0            0
# 아빠가 여자를 좋아해                      0  ...             0            0
# 하모니                              0  ...             0            0
# 의형제                              0  ...             0            0
# 평행 이론                            0  ...             0            0
#
#              director_황철민  time  dir_prev_bfnum  dir_prev_num  num_staff  \
# title
# 용서는 없다                  0   125    3.005290e+05             2        304
# 아빠가 여자를 좋아해             0   113    3.427002e+05             4        275
# 하모니                     0   115    4.206611e+06             3        419
# 의형제                     0   116    6.913420e+05             2        408
# 평행 이론                   0   110    3.173800e+04             1        380
#
#              num_actor  total_dir_prev         Label
# title
# 용서는 없다               3    1.502655e+05    938.284900
# 아빠가 여자를 좋아해          3    1.713521e+05   1069.951327
# 하모니                  7    2.103307e+06  13133.304358
# 의형제                  2    3.456720e+05   2158.427869
# 평행 이론                1    1.586950e+04     99.101864
#
# [5 rows x 1013 columns]

# %%
prediction_huber['Label']
# Out:
# title
# 용서는 없다               938.284900
# 아빠가 여자를 좋아해         1069.951327
# 하모니                13133.304358
# 의형제                 2158.427869
# 평행 이론                 99.101864
#                        ...
# 해에게서 소년에게              8.091269
# 울보 권투부              2259.176380
# 어떤살인                2259.181310
# 말하지 못한 비밀            158.292335
# 조선안방 스캔들-칠거지악 2     2259.175962
# Name: Label, Length: 243, dtype: float64

# %%
submission.head()
# Out:
#              box_off_num
# title
# 용서는 없다                 0
# 아빠가 여자를 좋아해            0
# 하모니                    0
# 의형제                    0
# 평행 이론                  0

# %%
submission['box_off_num'] = prediction_huber['Label']
submission.to_csv('automl_prediction_huber.csv')
